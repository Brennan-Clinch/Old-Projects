# %%
#Import libraries
import os 
import numpy as np
import pandas as pd
os.chdir("C:\\Users\\JCCLI\\Downloads")
winedata = pd.read_csv("winedat.csv")

winedata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120974 entries, 0 to 120973
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   id                     120974 non-null  int64
#  1   country                120974 non-null  object
#  2   description            120974 non-null  object
#  3   points                 120974 non-null  int64
#  4   price                  120974 non-null  int64
#  5   province               120974 non-null  object
#  6   region_1               120974 non-null  object
#  7   taster_name            120974 non-null  object
#  8   taster_twitter_handle  120974 non-null  object
#  9   title                  120974 non-null  object
#  10  variety                120973 non-null  object
#  11  winery                 120974 non-null  object
# dtypes: int64(3), object(9)
# memory usage: 11.1+ MB

# %%
winedata.head(20)
# Out:
#     id    country                                        description  points  \
# 0    2   Portugal  This is ripe and fruity, a wine that is smooth...      87
# 1    3         US  Tart and snappy, the flavors of lime flesh and...      87
# 2    4         US  Pineapple rind, lemon pith and orange blossom ...      87
# 3    5         US  Much like the regular bottling from 2012, this...      87
# 4    6      Spain  Blackberry and raspberry aromas show a typical...      87
# 5    7      Italy  Here's a bright, informal red that opens with ...      87
# 6    8     France  This dry and restrained wine offers spice in p...      87
# 7    9    Germany  Savory dried thyme notes accent sunnier flavor...      87
# 8   10     France  This has great depth of flavor with its fresh ...      87
# 9   11         US  Soft, supple plum envelopes an oaky structure ...      87
# 10  12     France  This is a dry wine, very spicy, with a tight, ...      87
# 11  13         US  Slightly reduced, this wine offers a chalky, t...      87
# 12  15         US  Building on 150 years and six generations of w...      87
# 13  16    Germany  Zesty orange peels and apple notes abound in t...      87
# 14  17  Argentina  Baked plum, molasses, balsamic vinegar and che...      87
# 15  18  Argentina  Raw black-cherry aromas are direct and simple ...      87
# 16  19      Spain  Desiccated blackberry, leather, charred wood a...      87
# 17  20         US  Red fruit aromas pervade on the nose, with cig...      87
# 18  21         US  Ripe aromas of dark berries mingle with ample ...      87
# 19  22         US  A sleek mix of tart berry, stem and herb, alon...      87
#
#     price           province                 region_1         taster_name  \
# 0      15              Douro  no information provided          Roger Voss
# 1      14             Oregon        Willamette Valley        Paul Gregutt
# 2      13           Michigan      Lake Michigan Shore  Alexander Peartree
# 3      65             Oregon        Willamette Valley        Paul Gregutt
# 4      15     Northern Spain                  Navarra   Michael Schachner
# 5      16  Sicily & Sardinia                 Vittoria       Kerin O’Keefe
# 6      24             Alsace                   Alsace          Roger Voss
# 7      12        Rheinhessen  no information provided  Anna Lee C. Iijima
# 8      27             Alsace                   Alsace          Roger Voss
# 9      19         California              Napa Valley      Virginie Boone
# 10     30             Alsace                   Alsace          Roger Voss
# 11     34         California         Alexander Valley      Virginie Boone
# 12     12         California            Central Coast       Matt Kettmann
# 13     24              Mosel  no information provided  Anna Lee C. Iijima
# 14     30              Other                 Cafayate   Michael Schachner
# 15     13   Mendoza Province                  Mendoza   Michael Schachner
# 16     28     Northern Spain         Ribera del Duero   Michael Schachner
# 17     32           Virginia                 Virginia  Alexander Peartree
# 18     23           Virginia                 Virginia  Alexander Peartree
# 19     20             Oregon                   Oregon        Paul Gregutt
#
#       taster_twitter_handle  \
# 0                @vossroger
# 1               @paulgwine
# 2   no information provided
# 3               @paulgwine
# 4               @wineschach
# 5              @kerinokeefe
# 6                @vossroger
# 7   no information provided
# 8                @vossroger
# 9                   @vboone
# 10               @vossroger
# 11                  @vboone
# 12            @mattkettmann
# 13  no information provided
# 14              @wineschach
# 15              @wineschach
# 16              @wineschach
# 17  no information provided
# 18  no information provided
# 19              @paulgwine
#
#                                                 title             variety  \
# 0       Quinta dos Avidagos 2011 Avidagos Red (Douro)      Portuguese Red
# 1       Rainstorm 2013 Pinot Gris (Willamette Valley)          Pinot Gris
# 2   St. Julian 2013 Reserve Late Harvest Riesling ...            Riesling
# 3   Sweet Cheeks 2012 Vintner's Reserve Wild Child...          Pinot Noir
# 4   Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...  Tempranillo-Merlot
# 5    Terre di Giurfo 2013 Belsito Frappato (Vittoria)            Frappato
# 6               Trimbach 2012 Gewurztraminer (Alsace)      Gewürztraminer
# 7   Heinz Eifel 2013 Shine Gewürztraminer (Rheinhe...      Gewürztraminer
# 8   Jean-Baptiste Adam 2012 Les Natures Pinot Gris...          Pinot Gris
# 9   Kirkland Signature 2011 Mountain Cuvée Caberne...  Cabernet Sauvignon
# 10            Leon Beyer 2012 Gewurztraminer (Alsace)      Gewürztraminer
# 11  Louis M. Martini 2012 Cabernet Sauvignon (Alex...  Cabernet Sauvignon
# 12           Mirassou 2012 Chardonnay (Central Coast)          Chardonnay
# 13        Richard Böcking 2013 Devon Riesling (Mosel)            Riesling
# 14         Felix Lavaque 2010 Felix Malbec (Cafayate)              Malbec
# 15  Gaucho Andino 2011 Winemaker Selection Malbec ...              Malbec
# 16  Pradorey 2010 Vendimia Seleccionada Finca Vald...   Tempranillo Blend
# 17               Quiévremont 2012 Meritage (Virginia)            Meritage
# 18      Quiévremont 2012 Vin de Maison Red (Virginia)           Red Blend
# 19                   Acrobat 2013 Pinot Noir (Oregon)          Pinot Noir
#
#                  winery
# 0   Quinta dos Avidagos
# 1             Rainstorm
# 2            St. Julian
# 3          Sweet Cheeks
# 4                Tandem
# 5       Terre di Giurfo
# 6              Trimbach
# 7           Heinz Eifel
# 8    Jean-Baptiste Adam
# 9    Kirkland Signature
# 10           Leon Beyer
# 11     Louis M. Martini
# 12             Mirassou
# 13      Richard Böcking
# 14        Felix Lavaque
# 15        Gaucho Andino
# 16             Pradorey
# 17          Quiévremont
# 18          Quiévremont
# 19              Acrobat

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# Drop Description column

winedata.describe()
# Out:
#                   id         points          price
# count  120974.000000  120974.000000  120974.000000
# mean    65046.254617      88.421834      35.363268
# std     37511.803046       3.044478      41.022366
# min         2.000000      80.000000       4.000000
# 25%     32575.250000      86.000000      17.000000
# 50%     65144.500000      88.000000      25.000000
# 75%     97506.750000      91.000000      42.000000
# max    129971.000000     100.000000    3300.000000

# %%
# Create Boxplots of results

import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
fig = plt.figure(figsize =(10, 7))

plt.boxplot(winedata['points'])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [22], in <cell line: 5>()
#       3 import matplotlib.pyplot as plt
#       4 import matplotlib
# ----> 5 import seaborn as sns
#       6 fig = plt.figure(figsize =(10, 7))
#       8 plt.boxplot(winedata['points'])
#
# ModuleNotFoundError: No module named 'seaborn'
