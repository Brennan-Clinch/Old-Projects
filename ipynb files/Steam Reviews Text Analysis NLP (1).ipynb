# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import scipy 
from scipy.spatial.distance import cdist

import matplotlib.pyplot as plt
import time
from sklearn.cluster import KMeans, MiniBatchKMeans, DBSCAN
from sklearn.feature_extraction.text import *
from sklearn.feature_selection import *
from sklearn.preprocessing import *
from sklearn.feature_extraction import text
from sklearn.feature_selection import VarianceThreshold



import time

from wordcloud import WordCloud

import dill

# %%
start = time.time()
df = pd.read_csv('C://Users//JCCLI//steam_reviews.csv', nrows=3000000) # Every 2000000 rows occupy ~1GB of main memory and it takes ~21 sec to fetch the data
print("time to fetch data=", time.time()-start)
df.head(5)
# Out:
# time to fetch data= 225.61170887947083
#    Unnamed: 0  app_id                  app_name  review_id  language  \
# 0           0  292030  The Witcher 3: Wild Hunt   85185598  schinese
# 1           1  292030  The Witcher 3: Wild Hunt   85185250  schinese
# 2           2  292030  The Witcher 3: Wild Hunt   85185111  schinese
# 3           3  292030  The Witcher 3: Wild Hunt   85184605   english
# 4           4  292030  The Witcher 3: Wild Hunt   85184287  schinese
#
#                                               review  timestamp_created  \
# 0                            不玩此生遗憾，RPG游戏里的天花板，太吸引人了         1611381629
# 1                                 拔DIAO无情打桩机--杰洛特!!!         1611381030
# 2                                              巫师3NB         1611380800
# 3  One of the best RPG's of all time, worthy of a...         1611379970
# 4                                                 大作         1611379427
#
#    timestamp_updated  recommended  votes_helpful  ...  steam_purchase  \
# 0         1611381629         True              0  ...            True
# 1         1611381030         True              0  ...            True
# 2         1611380800         True              0  ...            True
# 3         1611379970         True              0  ...            True
# 4         1611379427         True              0  ...            True
#
#    received_for_free  written_during_early_access     author.steamid  \
# 0              False                        False  76561199095369542
# 1              False                        False  76561198949504115
# 2              False                        False  76561199090098988
# 3              False                        False  76561199054755373
# 4              False                        False  76561199028326951
#
#    author.num_games_owned  author.num_reviews  author.playtime_forever  \
# 0                       6                   2                   1909.0
# 1                      30                  10                   2764.0
# 2                       5                   1                   1061.0
# 3                       5                   3                   5587.0
# 4                       7                   4                    217.0
#
#    author.playtime_last_two_weeks  author.playtime_at_review  \
# 0                          1448.0                     1909.0
# 1                          2743.0                     2674.0
# 2                          1061.0                     1060.0
# 3                          3200.0                     5524.0
# 4                            42.0                      217.0
#
#    author.last_played
# 0        1.611343e+09
# 1        1.611386e+09
# 2        1.611384e+09
# 3        1.611384e+09
# 4        1.610788e+09
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df = df[df.language == 'english'].drop(columns=['Unnamed: 0','app_id','language','review_id', 'author.steamid'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1318048 entries, 3 to 2999997
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count    Dtype
# ---  ------                          --------------    -----
#  0   app_name                        1318048 non-null  object
#  1   review                          1315805 non-null  object
#  2   timestamp_created               1318048 non-null  int64
#  3   timestamp_updated               1318048 non-null  int64
#  4   recommended                     1318048 non-null  bool
#  5   votes_helpful                   1318048 non-null  int64
#  6   votes_funny                     1318048 non-null  int64
#  7   weighted_vote_score             1318048 non-null  float64
#  8   comment_count                   1318048 non-null  int64
#  9   steam_purchase                  1318048 non-null  bool
#  10  received_for_free               1318048 non-null  bool
#  11  written_during_early_access     1318048 non-null  bool
#  12  author.num_games_owned          1318048 non-null  int64
#  13  author.num_reviews              1318048 non-null  int64
#  14  author.playtime_forever         1318048 non-null  float64
#  15  author.playtime_last_two_weeks  1318048 non-null  float64
#  16  author.playtime_at_review       1315566 non-null  float64
#  17  author.last_played              1318048 non-null  float64
# dtypes: bool(4), float64(5), int64(7), object(2)
# memory usage: 155.9+ MB

# %%
df.hist(figsize=(20,10))
plt.show()

# %%
df["app_name"].hist(figsize=(20,15))
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ## Raw data clusters

# %%
vectorizer = TfidfVectorizer(stop_words='english')

vectorized_text = vectorizer.fit_transform(df['review'].fillna(' ').values)

# %%
app_name_oe = pd.get_dummies(df['app_name'], prefix='app_name', columns='app_name')
df_oe = pd.concat([df, app_name_oe], axis=1)

# %%
def vectorized_dataframe(df, vt):
    non_obj_cols = df[df.select_dtypes(exclude=['object', 'bool']).columns].fillna(0).values
    bool_cols = np.multiply(1, df[df.select_dtypes('bool').columns].values)

    vectorized_data = scipy.sparse.hstack((vt, non_obj_cols, bool_cols))
    return vectorized_data

data = vectorized_dataframe(df_oe, vectorized_text)

# %%
def elbow_method(X, K=range(2, 10)):
    inertias = {}
    models = {}

    for k in K:
        m = KMeans(n_clusters=k)
        m.fit(X)
        inertias[k] = m.inertia_
        models[k] = m

    return models, inertias

models, inertias = elbow_method(data)

# %%
def plot_inertias(inertias, title):
    plt.plot(inertias.keys(), inertias.values(), 'bx-')
    plt.xlabel('Values of K')
    plt.ylabel('Inertia')
    plt.title(title)
    plt.show()

plot_inertias(inertias, 'text data')

# %%
k = 5

def add_labels_to_df(df, k, model):
    df_wlabels = pd.concat(
        [
            df,
            pd.DataFrame(model.labels_, index=df.index, columns=['labels'])
        ], axis=1
    )
    plt.hist(df_wlabels["labels"], bins=k)
    plt.show()
    
    return df_wlabels

df_wlabels = add_labels_to_df(df, k, models[k])

# %%
def show_cluster_hist_features(df, k):
    for cluster_idx in range(k):
        print("cluster: ", cluster_idx)
        df[df["labels"] == cluster_idx].hist(figsize=(10,18))
        plt.show()

show_cluster_hist_features(df_wlabels, k)
# Out:
# cluster:  0
# cluster:  1
# cluster:  2
# cluster:  3
# cluster:  4

# %%
def show_cluster_hist_app_name(df, k):
    for cluster_idx in range(k):
        print("cluster: ", cluster_idx)
        df[df["labels"] == cluster_idx]["app_name"].hist(figsize=(10,8))
        plt.xticks(rotation = 90)
        plt.show()

show_cluster_hist_app_name(df_wlabels, k)
# Out:
# cluster:  0
# cluster:  1
# cluster:  2
# cluster:  3
# cluster:  4

# %%
def print_clusters_review(df, k):
    for cluster_idx in range(k):
        print("cluster: ", cluster_idx)
        print(df[df["labels"] == cluster_idx]["review"])

print_clusters_review(df_wlabels, k)
# Out:
# cluster:  0
# 236983                                         It's awesome.
# 238806                                  Great fun to be had!
# 239143                                      damn you're ugly
# 240404     Is it as good as people say it is?\n\n\nYep, i...
# 240870     Hands down one of the best game games that I'v...
#                                  ...
# 2999833    This is the most boring damn game I've played ...
# 2999859    I really enjoy this game even though there are...
# 2999860    After all these years the forest is a game tha...
# 2999881    Looking forward to the sequel Sons of the Forest.
# 2999989             havent played in 4 years, seems nice lol
# Name: review, Length: 353870, dtype: object
# cluster:  1
# 437019                                Best game of all time.
# 437049             Just amazing!\n\n\nNothing more to say...
# 437069     This game was the best game I've played since ...
# 437109                                       Excellent game!
# 437143          Awesome game, just wish there was more of it
#                                  ...
# 2999992    - Plane crashed.\n- Found axe\n- Chopped tree\...
# 2999993    EDIT -- Now a thumbs up\nMuch time has passed....
# 2999995    Game is so fun! I have spent hours playing wit...
# 2999996    This game is fantastic and I'd say it's showin...
# 2999997           awesome game, just very glitchy at times !
# Name: review, Length: 152728, dtype: object
# cluster:  2
# 471195                                   one of the classics
# 471737                   awesome. the starting point for fps
# 473855     Literally one of the best and most revolutiona...
# 474007                        100% deserves the hype it gets
# 478818     the games pretty cool, it didnt forever turn m...
#                                  ...
# 1734337    This game is completely addicting and a time s...
# 1734362    It's Civ, it has some issues but faithful to t...
# 1734401    If you like sitting on your ass waiting for pe...
# 1734410    Careful with this one ladies and gents... It w...
# 1734430                             Crack in video game form
# Name: review, Length: 1450, dtype: object
# cluster:  3
# 331695     I've never liked The Witcher series, Geralt's ...
# 338889     The written masterpiece perfectly executed int...
# 342842                                        Just excellent
# 344953                                              its good
# 345693     Incredible lore and story. Tried to avoid out ...
#                                  ...
# 2999975    Your alone in the forrest! ... well you wish y...
# 2999979                               Awesome Survival Game!
# 2999982    Nothing says fun like getting chased by a fat ...
# 2999985    Surrounded my treehouse with Spike Traps , usi...
# 2999987    i would like this game if it didnt go 2 frames...
# Name: review, Length: 124890, dtype: object
# cluster:  4
# 3          One of the best RPG's of all time, worthy of a...
# 5                     good story, good graphics. lots to do.
# 6                                                   dis gud,
# 18         favorite game of all time cant wait for the Ne...
# 20                                 Why wouldn't you get this
#                                  ...
# 2968243    This game is amazing and a must buy for any su...
# 2968333                                                 tree
# 2969834    think of the game in this way "" The Green Inf...
# 2970072    This game is really a lot of fun, especially n...
# 2973390                             ahhh cannibals nice food
# Name: review, Length: 685110, dtype: object

# %%
def frequencies_dict(cluster_index, model, k, centroids, terms):    
    frequencies = {}
    sorted_terms = []
    
    term_frequencies = model.cluster_centers_[cluster_index]
    sorted_idx = centroids[cluster_index]
    
    num_feature_not_str = len(df.select_dtypes(exclude='object').columns)
    
    for i in sorted_idx:
        if i < len(terms):
            frequencies[terms[i]] = term_frequencies[i]
            sorted_terms.append(terms[i])
    return frequencies, sorted_terms
def makeImage(frequencies):

    wc = WordCloud(background_color="white", max_words=50)
    # generate word cloud
    wc.generate_from_frequencies(frequencies)

    # show
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.show()
def show_cluster_top_terms(model, vectorizer, k):

    centroids = model.cluster_centers_.argsort()[:, ::-1] ## Indices of largest centroids' entries in descending order
    terms = vectorizer.get_feature_names()

    for cluster_idx in range(k):
        freq, sorted_terms = frequencies_dict(cluster_idx, model, k, centroids, terms)
        print("cluster: ", cluster_idx)
        makeImage(freq)

show_cluster_top_terms(models[k], vectorizer, k)
# Out:
# C:\Users\JCCLI\Miniconda_3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# cluster:  0
# cluster:  1
# cluster:  2
# cluster:  3
# cluster:  4

# %% [markdown]
# #### Data cleaning/ 1st iteration

# %%
def normalize_dataset(df):
    df_n = pd.DataFrame()
    for col in df.columns:
        if df[col].dtypes == 'float64' or df[col].dtypes == 'int64':
            df_n[col] = minmax_scale(df[col].fillna(0).values)
        else:
            df_n[col] = df[col]
    
    return df_n


df_n = normalize_dataset(df)

# %%
print(df_n[df_n.select_dtypes(exclude="object").columns].var())
# Out:
# timestamp_created                 0.049660
# timestamp_updated                 0.047447
# recommended                       0.059026
# votes_helpful                     0.000011
# votes_funny                       0.000035
# weighted_vote_score               0.058491
# comment_count                     0.000016
# steam_purchase                    0.161234
# received_for_free                 0.024751
# written_during_early_access       0.042168
# author.num_games_owned            0.000170
# author.num_reviews                0.000042
# author.playtime_forever           0.000235
# author.playtime_last_two_weeks    0.000970
# author.playtime_at_review         0.000133
# author.last_played                0.001993
# dtype: float64

# %%
def remove_feature_low_var(df):
    # Check boolean features
    sel = VarianceThreshold(threshold=(.8 * (1 - .8)))
    try:
        sel.fit_transform(df[df.select_dtypes('bool').columns].values)
        mask = sel.get_support()
        new_df_bool = df[df.select_dtypes('bool').columns].loc[:, mask]
        
        df_hv1 = pd.concat([new_df_bool, df[df.select_dtypes(exclude='bool').columns]], axis=1)
        
    except Exception as e:
        df_hv1 = df[df.select_dtypes(exclude='bool').columns]

    print("Dropped ", len(df.columns)-len(df_hv1.columns), "boolean features")    
    # Check non-boolean features
    sel = VarianceThreshold(threshold=.005)
    sel.fit_transform(df_hv1[df_hv1.select_dtypes(exclude=['object','bool']).columns].fillna(0).values)

    mask = sel.get_support()

    df_hv2 = df_hv1[df_hv1.select_dtypes(exclude=['object','bool']).columns].loc[:, mask]    
    
    df_hv2 = pd.concat([df_hv2, df_hv1[df_hv1.select_dtypes(['object', 'bool']).columns]], axis=1)
    
    print("Dropped ", len(df_hv1.columns)-len(df_hv2.columns), "non-boolean features")
    
    return df_hv2

df_hv = remove_feature_low_var(df_n)
# Out:
# Dropped  3 boolean features
# Dropped  9 non-boolean features

# %%
df_hv_oe = pd.concat([df_hv, app_name_oe], axis=1)
data = vectorized_dataframe(df_hv_oe, vectorized_text)
models, inertias = elbow_method(data)
plot_inertias(inertias, 'text data')

# %%
k = 5
df_hv_wlabels = add_labels_to_df(df_hv, k, models[k])
show_cluster_hist_features(df_hv_wlabels, k)
show_cluster_hist_app_name(df_hv_wlabels, k)
print_clusters_review(df_hv_wlabels, k)
show_cluster_top_terms(models[k], vectorizer, k)
# Out:
# cluster:  0
# cluster:  1
# cluster:  2
# cluster:  3
# cluster:  4
# cluster:  0
# cluster:  1
# cluster:  2
# cluster:  3
# cluster:  4
# cluster:  0
# 907626     great game, just dont leave then game for like...
# 907627                                                   NaN
# 907628                                                 sssss
# 907630                                 I have over 600 mods.
# 907631                                                 chad.
#                                  ...
# 1563145                                                eys\n
# 1563146    GOD3Q45T6Y6UJMNHYT8UK, NTF Berhgfq1qerf yqargh...
# 1563147                                     It's really fun.
# 1563148                                                Garry
# 1563149    despite not being able to join public server's...
# Name: review, Length: 331621, dtype: object
# cluster:  1
# 1734554                                                  Fun
# 1734555                      good horror and also funny game
# 1734556                                                  yes
# 1734557                                              g8 game
# 1734558       If you are considering purchasing Dead By D...
#                                  ...
# 2153442                                            game bad.
# 2153444                                                  yes
# 2153445    The developers are straight up assholes.\n\nDo...
# 2153446                                                  yes
# 2153448    whenever I play a game with cheryl mason, I ge...
# Name: review, Length: 143988, dtype: object
# cluster:  2
# 469413     I don't own this game why can I write a review...
# 469438     The original Half-Life trilogy will forever be...
# 469441     While it is really showing its age at this poi...
# 469442                             Shitty garfield kart copy
# 469446                                                  anal
#                                  ...
# 2999938    The game is fun for about 3-4 hours, then its ...
# 2999953    Really good fun, will be crazy in-depth once a...
# 2999954    Attempted to ride a shark then it killed me. \...
# 2999990    Like it, hard as balls to survive more than 5 ...
# 2999995    Game is so fun! I have spent hours playing wit...
# Name: review, Length: 160470, dtype: object
# cluster:  3
# 469395           the platforming makes me want to eat sand\n
# 469396                      Really fun, great story an crap.
# 469398                                                  good
# 469399     hey, sorry i saw your profile and i just thoug...
# 469400                                                  yes.
#                                  ...
# 2999989             havent played in 4 years, seems nice lol
# 2999992    - Plane crashed.\n- Found axe\n- Chopped tree\...
# 2999993    EDIT -- Now a thumbs up\nMuch time has passed....
# 2999996    This game is fantastic and I'd say it's showin...
# 2999997           awesome game, just very glitchy at times !
# Name: review, Length: 530509, dtype: object
# cluster:  4
# 3         One of the best RPG's of all time, worthy of a...
# 5                    good story, good graphics. lots to do.
# 6                                                  dis gud,
# 18        favorite game of all time cant wait for the Ne...
# 20                                Why wouldn't you get this
#                                 ...
# 469388                           had sex on a unicorn 10/10
# 469389    Edit:\n\nThe third installment of the Witcher ...
# 469390        Why am i still throwing money at the screen ?
# 469391         Its good.\n\nGeralt is life. Geralt is love.
# 469392    downgraded piece of shit.\nbut if you like bra...
# Name: review, Length: 151460, dtype: object
# C:\Users\JCCLI\Miniconda_3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# cluster:  0
# cluster:  1
# cluster:  2
# cluster:  3
# cluster:  4
