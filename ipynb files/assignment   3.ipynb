# %%
#problem1
class Person(object):
    numPerson = 0
    def __init__(self, name):
        self.name = name
    def self_name(self):
        print(self.name)
class Employee(Person):
    numEmployee = 0
    def __init__(self, name, age, pay, ID):
        super(Employee, self).__init__(name)
        self.age = age
        self.pay = pay
        self.employeeID = ID
        Employee.numEmployee += 1
    def employee_data(self):
        print(self.name, self.age, 'pay rate:',self.pay, 'employee ID:' , self.employeeID)

# %%
#problem 2
class Employee(object):
    numEmployee = 0
    def __init__(self, name, age, pay, ID):
        self.name = name
        self.age = age
        self.pay = pay
        self.employeeID = ID
        Employee.numEmployee += 1
    def employee_data(self):
        print(self.name, self.age, self.pay, self.employeeID)
class Programmer(Employee):
    def __init__(self, name, age, pay, ID, proLang):
        super().__init__(name, age, pay, ID)
        self.proLang = proLang
    def program_language(self):
        print(self.name,self.age,'pay rate:', self.pay,'employee ID:', self.employeeID, 'programming language:',self.proLang)

# %%
#problem 3
class Employee(object):
    numEmployee = 0
    def __init__(self, name, age, pay, ID):
        self.name = 'Brennan'
        self.age = age
        self.pay = pay
        self.employeeID = ID
        Employee.numEmployee += 1
    def employee_data(self):
        print(self.name, self.age, self.pay, self.employeeID)
class Manager(Employee):
    def __init__(self, name, age, pay, ID, progList):
        super().__init__(name, age, pay, ID)
        self.progList = ['Brennan']
        self.progList = []
       
    def addProgrammer(self):
        self.progList.append('Brennan'),self.progList.append('Jacob'),self.progList.append('John')
        print(self.progList)
    def removeProgrammer(self):
        if len(self.progList)==0:
            pass
        else:
            self.progList.pop(0)
        
        print(self.progList)

# %%
#problem 4
class Employee(object):
    numEmployee = 0
    def __init__(self, name, age, pay, ID):
        self.name = name
        self.age = age
        self.pay = pay
        self.employeeID = ID
        Employee.numEmployee += 1
    def employee_data(self):
        print(self.name, self.age, self.pay, self.employeeID)
class Programmer(Employee):
    def __init__(self, name, age, pay, ID, proLang):
        super().__init__(name, age, pay, ID)
        self.proLang = proLang
    def program_language(self):
        print(self.name, self.age, 'pay:', self.pay, 'ID', self.employeeID, 'Programming language:',self.proLang)
class Manager(Employee):
    def __init__(self, name, age, pay, ID, progList):
        super().__init__(name, age, pay, ID)
        self.progList = ['Brennan']
        self.progList = []
       
    def addProgrammer(self):
        self.progList.append('Brennan'),self.progList.append('Jacob'),self.progList.append('John')
        print(self.progList)
    def removeProgrammer(self):
        if len(self.progList)==0:
            pass
        else:
            self.progList.pop(0)
        
        print(self.progList)
#3 function calls to create 3 programmers, with arbitrary names and programming languages
print('The three programmers are:')
x = Programmer('Brennan', 20, 8.25, 849066560, 'python')
y = Programmer('Jacob: age', 34,13.50, 7774459, 'java')
z = Programmer('John: age', 23, 18.50, 4432297, 'c++')

x.program_language()
y.program_language()
z.program_language()
#1 function call to create 1 manager

print('the initial manager list:')
man = Manager(' ', 9,9,9,2)
man.removeProgrammer()
# programmers to add to manager's programming list
print('the manager list of the three programmers:')
man.addProgrammer()
print('manager list after first employee removed:')
man.removeProgrammer()
